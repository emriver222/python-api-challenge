# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from scipy.stats import linregress
import random
from datetime import datetime
import json

# Import API key
from api_keys import weather_api_key

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# %% [markdown]
# ### API Call

# %%
# Out:
# [{'city_name': 'Minneapolis',
#   'lat': 44.977753,
#   'lon': -93.265011,
#   'main': {'temp': 1.35,
#    'temp_min': 0.49,
#    'temp_max': 1.94,
#    'feels_like': -11.22,
#    'pressure': 1031,
#    'humidity': 45},
#   'wind': {'speed': 10.29, 'deg': 330},
#   'clouds': {'all': 90},
#   'weather': [{'id': 804,
#     'main': 'Clouds',
#     'description': 'overcast clouds',
#     'icon': '04n'}],
#   'dt': 283996800,
#   'dt_iso': '1979-01-01 00:00:00 +0000 UTC',
#   'timezone': -21600},
#  {'city_name': 'Minneapolis',
#   'lat': 44.977753,
#   'lon': -93.265011,
#   'main': {'temp': 1.02,
#    'temp_min': 0.62,
#    'temp_max': 1.46,
#    'feels_like': -10.89,
#    'pressure': 1031,
#    'humidity': 47},
#   'wind': {'speed': 9.17, 'deg': 310},
#   'clouds': {'all': 90},
#   'weather': [{'id': 804,
#     'main': 'Clouds',
#     'description': 'overcast clouds',
#     'icon': '04n'}],
#   'dt': 284000400,
#   'dt_iso': '1979-01-01 01:00:00 +0000 UTC',
#   'timezone': -21600},
# ...

# %%
#url = "http://api.openweathermap.org/data/2.5/weather?q=Minneapolis,US&"
#units = "metric"

#test_url = f"{url}appid={weather_api_key}"

#test_url = query_url + "minneapolis"
#print(test_url)


#FOR HISTORICAL UPON GETTING DATASET
#url = "http://history.openweathermap.org/data/2.5/history/city?"

#test_url = f"{url}q=Minneapolis,US&appid={weather_api_key}"
# Out:
# http://api.openweathermap.org/data/2.5/weather?q=Minneapolis,US&appid=35a2fe42f7de39aa581e67b1cb8cf77b

# %%
#response = requests.get(test_url).json()

#print(response)
# Out:
# {'coord': {'lon': -93.26, 'lat': 44.98}, 'weather': [{'id': 803, 'main': 'Clouds', 'description': 'broken clouds', 'icon': '04d'}], 'base': 'stations', 'main': {'temp': 282.99, 'feels_like': 272.85, 'temp_min': 281.48, 'temp_max': 284.15, 'pressure': 1002, 'humidity': 53}, 'visibility': 16093, 'wind': {'speed': 11.8, 'deg': 330, 'gust': 19}, 'clouds': {'all': 75}, 'dt': 1587426756, 'sys': {'type': 1, 'id': 4984, 'country': 'US', 'sunrise': 1587381519, 'sunset': 1587431075}, 'timezone': -18000, 'id': 5037649, 'name': 'Minneapolis', 'cod': 200}

# %%
city = (data[0])


print(city)
# Out:
# {'city_name': 'Minneapolis', 'lat': 44.977753, 'lon': -93.265011, 'main': {'temp': 1.35, 'temp_min': 0.49, 'temp_max': 1.94, 'feels_like': -11.22, 'pressure': 1031, 'humidity': 45}, 'wind': {'speed': 10.29, 'deg': 330}, 'clouds': {'all': 90}, 'weather': [{'id': 804, 'main': 'Clouds', 'description': 'overcast clouds', 'icon': '04n'}], 'dt': 283996800, 'dt_iso': '1979-01-01 00:00:00 +0000 UTC', 'timezone': -21600}

# %%
# Out:
# {'city_name': 'Minneapolis', 'lat': 44.977753, 'lon': -93.265011, 'main': {'temp': 1.02, 'temp_min': 0.62, 'temp_max': 1.46, 'feels_like': -10.89, 'pressure': 1031, 'humidity': 47}, 'wind': {'speed': 9.17, 'deg': 310}, 'clouds': {'all': 90}, 'weather': [{'id': 804, 'main': 'Clouds', 'description': 'overcast clouds', 'icon': '04n'}], 'dt': 284000400, 'dt_iso': '1979-01-01 01:00:00 +0000 UTC', 'timezone': -21600}

# %%
weather = weather_des[0]

weather_final = weather['description']
print(weather_final)
# Out:
# broken clouds

# %% [markdown]
# ### Convert Raw Data to DataFrame

# %%
dict = {"city": city,
        "temp": temp,
        "humidity": humidity,
        "cloud": cloud,
        "wind": wind,
        "weather description": weather_final
         
}
        
print(dict)
# Out:
# {'city': 'Minneapolis', 'temp': 282.99, 'humidity': 53, 'cloud': 75, 'wind': 11.8, 'weather description': 'broken clouds'}

# %%
df = pd.DataFrame(dict, index=[0])
df
# Out:
#           city    temp  humidity  cloud  wind weather description
# 0  Minneapolis  282.99        53     75  11.8       broken clouds
